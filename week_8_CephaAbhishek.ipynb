# %% [markdown]
# <a href="https://colab.research.google.com/github/cephav/Celebal_Assignment/blob/main/week_8_CephaAbhishek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 Single Agent Pipeline Project
#
# ## Problem Statement
# Build a **Single-Agent Smart Assistant** that:
# - Understands user queries
# - Routes tasks based on intent
# - Uses tools when required
# - Returns structured JSON output
#
# ### The agent should handle:
# - Math queries → Calculator Tool
# - Keyword extraction → Keyword Tool
# - General queries → Direct response
#
# ---
# ### 🛠️ What You Need to Implement
# - Agent logic
# - Conditional routing
# - Tool integration
# - Basic error handling
#
# ### 🚀 Bonus
# - Improve routing
# - Add logging
# - Add more tools

# %%
# 🛠️ TOOL 1: Calculator

def calculator(expression: str) -> str:
    """Evaluate a mathematical expression."""
    try:
        return str(eval(expression))
    except Exception:
        return "Error in calculation"

# %%
# 🛠️ TOOL 2: Keyword Extractor

def extract_keywords(text: str) -> list:
    """Extract keywords from text."""
    try:
        words = text.split()
        keywords = list(set([w.lower() for w in words if len(w) > 4]))
        return keywords[:5]
    except Exception:
        return []

# %% [markdown]
# ## 🤖 Implement Agent Logic Below
#
# 👉 Use conditional routing:
# - If query contains "calculate" → use calculator
# - If query contains "keywords" → use keyword extractor
# - Else → general response

# %%
import re

# 🤖 AGENT FUNCTION (TO IMPLEMENT)

def agent(query: str):
    query_lower = query.lower()

    if "calculate" in query_lower:
        try:
            # Extract the expression. Assuming the expression follows "calculate "
            match = re.search(r"calculate\s+(.*)", query_lower)
            if match:
                expression = match.group(1).strip()
                result = calculator(expression)
                return {
                    "type": "calculation",
                    "result": result
                }
            else:
                return {
                    "type": "error",
                    "result": "Could not parse calculation expression."
                }
        except Exception as e:
            return {
                "type": "error",
                "result": f"Error during calculation: {e}"
            }
    elif "keywords" in query_lower:
        try:
            # Extract text for keyword extraction. Assuming text follows "keywords from "
            match = re.search(r"keywords from\s+(.*)", query_lower)
            if match:
                text = match.group(1).strip()
                result = extract_keywords(text)
                return {
                    "type": "keywords",
                    "result": result
                }
            else:
                return {
                    "type": "error",
                    "result": "Could not parse text for keyword extraction."
                }
        except Exception as e:
            return {
                "type": "error",
                "result": f"Error during keyword extraction: {e}"
            }
    else:
        return {
            "type": "general",
            "result": "I'm not equipped to handle that specific query yet. How else can I assist?"
        }

# %% [markdown]
# ## 📦 Expected Output Format
#
# ```
# {
#   "type": "calculation / keywords / general / error",
#   "result": ...
# }
# ```

# %%
# 🧪 Test Cases

queries = [
    "Calculate 20 + 5",
    "Extract keywords from Artificial Intelligence is transforming industries",
    "What is machine learning?"
]

for q in queries:
    print("Query:", q)
    print("Response:", agent(q))
    print("-" * 50)
# Out:
# Query: Calculate 20 + 5
# Response: {'type': 'calculation', 'result': '25'}
# --------------------------------------------------
# Query: Extract keywords from Artificial Intelligence is transforming industries
# Response: {'type': 'keywords', 'result': ['intelligence', 'transforming', 'industries', 'artificial']}
# --------------------------------------------------
# Query: What is machine learning?
# Response: {'type': 'general', 'result': "I'm not equipped to handle that specific query yet. How else can I assist?"}
# --------------------------------------------------

# %%
# 🎯 Interactive Mode

while True:
    user_input = input("Enter query (type 'exit' to stop): ")
    if user_input.lower() == "exit":
        break
    print("Response:", agent(user_input))
# Out:
# Enter query (type 'exit' to stop): extract keywords from my name is cepha abhishek
# Response: {'type': 'keywords', 'result': ['cepha', 'abhishek']}
# Enter query (type 'exit' to stop): what is ML?
# Response: {'type': 'general', 'result': "I'm not equipped to handle that specific query yet. How else can I assist?"}
# Enter query (type 'exit' to stop): what is machine learning?
# Response: {'type': 'general', 'result': "I'm not equipped to handle that specific query yet. How else can I assist?"}
# Enter query (type 'exit' to stop): Calculate 22424*4421
# Response: {'type': 'calculation', 'result': '99136504'}
# Enter query (type 'exit' to stop): exit
